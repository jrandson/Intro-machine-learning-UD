# %%
import os
d = os.listdir('/')
print(d)
# Out:
# ['lib', 'boot', 'mnt', 'sys', 'srv', 'sbin', 'var', 'root', 'vmlinuz.old', 'tmp', 'run', 'opt', 'media', 'proc', 'initrd.img.old', 'lib64', 'home', 'vmlinuz', 'bin', '0', 'etc', 'lost+found', 'usr', 'initrd.img', 'dev']
