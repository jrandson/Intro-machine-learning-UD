# %%
import sklearn.linear_model.Lasso

features, labels = GetMyData()

regression  = Lasso()
regression.fit(features)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-1-8f1534b80675> in <module>()
# ----> 1 import sklearn.linear_model.Lasso
#       2
#       3 features, labels = GetMyData()
#       4
#
# ImportError: No module named Lasso
